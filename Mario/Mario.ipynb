# %%
# !pip install gym_super_mario_bros==7.3.0

# %%
# !pip install nes_py

# %%
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
#Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
done = True
for step in range(100000):
    if done:
        env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    env.render()
env.close()

# %% [markdown]
# # Preprocess Environment

# %%
# !pip install stable-baselines3[extra]

# %%
from gym.wrappers import FrameStack, GrayScaleObservation
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from matplotlib import pyplot as plt

# %%
#Base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
#Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)
#Grayscale
env = GrayScaleObservation(env, keep_dim = True)
#Dummy environment
env = DummyVecEnv([lambda:env])
#Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state.shape
# Out:
# (1, 240, 256, 4)

# %%
state, reward, done, info = env.step([env.action_space.sample()])

# %%
plt.figure(figsize=(10,8))
for idx in range(state.shape[3]):
    plt.subplot(1,4, idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # Train the RL Model

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def __init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq = 10000, save_path = CHECKPOINT_DIR)

# %%
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.0001, n_steps=512)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_2
# ----------------------------
# | time/              |     |
# |    fps             | 113 |
# |    iterations      | 1   |
# |    time_elapsed    | 4   |
# |    total_timesteps | 512 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 2           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.012356691 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.00121    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.47        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 64          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 3           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.013361715 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -0.143      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.5         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 31.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 4           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.025179796 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.33        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 4.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 5           |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.015722163 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.233       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 6           |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.006831206 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.25        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000497    |
# |    value_loss           | 3.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 7           |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.025824118 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.498       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 5.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 8           |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018230481 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.0241     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.195       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 9.75e-05    |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 9           |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.011280112 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.208       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 10          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009865355 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.0957      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0697      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.558       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 11          |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.009659359 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | -0.00507    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.16        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 12          |
# |    time_elapsed         | 711         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011307303 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.17       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.171       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 0.549       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 13          |
# |    time_elapsed         | 781         |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.013161514 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.046      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0934      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 0.268       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 14          |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.012235119 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0383      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 15          |
# |    time_elapsed         | 922         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.008425051 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.126       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 16          |
# |    time_elapsed         | 991         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022077482 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -0.107      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0293      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 0.209       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 8         |
# |    iterations           | 17        |
# |    time_elapsed         | 1059      |
# |    total_timesteps      | 8704      |
# | train/                  |           |
# |    approx_kl            | 1.1145256 |
# |    clip_fraction        | 0.918     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.511    |
# |    explained_variance   | 0.00231   |
# |    learning_rate        | 0.0001    |
# |    loss                 | 9.01      |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 0.333     |
# |    value_loss           | 85.7      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 18          |
# |    time_elapsed         | 1125        |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.025088364 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.0549      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 18.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00547     |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 19          |
# |    time_elapsed         | 1195        |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.009715877 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 20          |
# |    time_elapsed         | 1266        |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017354757 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.391      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 21          |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.017520249 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 55.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 22         |
# |    time_elapsed         | 1402       |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.01032795 |
# |    clip_fraction        | 0.0926     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.638     |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.38       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00767   |
# |    value_loss           | 28.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 23          |
# |    time_elapsed         | 1473        |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.019924708 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0078      |
# |    value_loss           | 77.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 24         |
# |    time_elapsed         | 1544       |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.12818667 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.244     |
# |    explained_variance   | 0.375      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 18.8       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0157     |
# |    value_loss           | 219        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 25           |
# |    time_elapsed         | 1626         |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0027117587 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.168       |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 14.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00181      |
# |    value_loss           | 71.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 26          |
# |    time_elapsed         | 1703        |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.008689526 |
# |    clip_fraction        | 0.00898     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.064      |
# |    explained_variance   | 0.0192      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 74.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 286         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 27          |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.013138441 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 57.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 28         |
# |    time_elapsed         | 1879       |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.16540225 |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.708     |
# |    explained_variance   | 0.685      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.13       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0143     |
# |    value_loss           | 16.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 29          |
# |    time_elapsed         | 1952        |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.018105088 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0306      |
# |    value_loss           | 40          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 30         |
# |    time_elapsed         | 2024       |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.31127647 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.803     |
# |    explained_variance   | -0.112     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.992      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0746     |
# |    value_loss           | 8.7        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 31         |
# |    time_elapsed         | 2102       |
# |    total_timesteps      | 15872      |
# | train/                  |            |
# |    approx_kl            | 0.00955399 |
# |    clip_fraction        | 0.336      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | -0.311     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.09       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0123     |
# |    value_loss           | 8.01       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 32         |
# |    time_elapsed         | 2192       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.10999065 |
# |    clip_fraction        | 0.642      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | -0.462     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.09       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0504     |
# |    value_loss           | 3.69       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 33          |
# |    time_elapsed         | 2264        |
# |    total_timesteps      | 16896       |
# | train/                  |             |
# |    approx_kl            | 0.013739649 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 53.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 80.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 34          |
# |    time_elapsed         | 2341        |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.019440344 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.138      |
# |    explained_variance   | 0.0757      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 164         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 35         |
# |    time_elapsed         | 2425       |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.01785919 |
# |    clip_fraction        | 0.0176     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.119     |
# |    explained_variance   | 0.0264     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 131        |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.00565   |
# |    value_loss           | 263        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 36          |
# |    time_elapsed         | 2515        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009290369 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.23        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 40.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 37          |
# |    time_elapsed         | 2604        |
# |    total_timesteps      | 18944       |
# | train/                  |             |
# |    approx_kl            | 0.014749842 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 155         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 206         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 38          |
# |    time_elapsed         | 2693        |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.023596484 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0208      |
# |    value_loss           | 49          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 39         |
# |    time_elapsed         | 2783       |
# |    total_timesteps      | 19968      |
# | train/                  |            |
# |    approx_kl            | 0.17416696 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.859     |
# |    explained_variance   | 0.128      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.69       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0306     |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 40           |
# |    time_elapsed         | 2868         |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0072303917 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.722       |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.48         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00206      |
# |    value_loss           | 6.42         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 41           |
# |    time_elapsed         | 2950         |
# |    total_timesteps      | 20992        |
# | train/                  |              |
# |    approx_kl            | 0.0045187324 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.264        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00404      |
# |    value_loss           | 6.41         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 42          |
# |    time_elapsed         | 3035        |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.013707735 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.286       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00348     |
# |    value_loss           | 5.93        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 43           |
# |    time_elapsed         | 3118         |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 0.0024081983 |
# |    clip_fraction        | 0.0891       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.722       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.365        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.0124       |
# |    value_loss           | 3.59         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 44          |
# |    time_elapsed         | 3209        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.029615121 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.14        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00874     |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 45          |
# |    time_elapsed         | 3328        |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.022287117 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.118       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0074      |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 46          |
# |    time_elapsed         | 3412        |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.005086939 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.0636     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.114       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00244     |
# |    value_loss           | 1.75        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 47           |
# |    time_elapsed         | 3498         |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 0.0042759078 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.179        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000991     |
# |    value_loss           | 0.827        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 48          |
# |    time_elapsed         | 3582        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012926229 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0578      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.308       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 49           |
# |    time_elapsed         | 3666         |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0065325764 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.0348       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0843       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 0.225        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 50           |
# |    time_elapsed         | 3750         |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0021092799 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0631       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000114     |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 51           |
# |    time_elapsed         | 3838         |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0031612818 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0437       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 52           |
# |    time_elapsed         | 3964         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0022125961 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0501       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00163      |
# |    value_loss           | 0.157        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 53          |
# |    time_elapsed         | 4047        |
# |    total_timesteps      | 27136       |
# | train/                  |             |
# |    approx_kl            | 0.092068136 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.202      |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.46        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0438      |
# |    value_loss           | 28.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 54          |
# |    time_elapsed         | 4127        |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.011911109 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0374     |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 24.3        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00197     |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 55            |
# |    time_elapsed         | 4216          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 0.00010009552 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0158       |
# |    explained_variance   | 0.448         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 50.2          |
# |    n_updates            | 540           |
# |    policy_gradient_loss | 0.00112       |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 56            |
# |    time_elapsed         | 4313          |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00087989273 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0179       |
# |    explained_variance   | -0.39         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.913         |
# |    n_updates            | 550           |
# |    policy_gradient_loss | 0.00316       |
# |    value_loss           | 8.02          |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-4f9d496705d2> in <module>
# ----> 1 model.learn(total_timesteps=1000000, callback=callback)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297     ) -> "PPO":
#     298
# --> 299         return super(PPO, self).learn(
#     300             total_timesteps=total_timesteps,
#     301             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     255                 self.logger.dump(step=self.num_timesteps)
#     256
# --> 257             self.train()
#     258
#     259         callback.on_training_end()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in train(self)
#     257                 # Optimization step
#     258                 self.policy.optimizer.zero_grad()
# --> 259                 loss.backward()
#     260                 # Clip grad norm
#     261                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# # Test

# %%
model = PPO.load('./train/best_model_30000')

# %%
state = env.reset()
while True:
    action, _state = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# C:\Users\jerem\anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d1f0259bbfd0> in <module>
#       1 state = env.reset()
#       2 while True:
# ----> 3     action, _state = model.predict(state)
#       4     state, reward, done, info = env.step(action)
#       5     env.render()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\base_class.py in predict(self, observation, state, mask, deterministic)
#     550             (used in recurrent policies)
#     551         """
# --> 552         return self.policy.predict(observation, state, mask, deterministic)
#     553
#     554     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in predict(self, observation, state, mask, deterministic)
#     334
#     335         with th.no_grad():
# --> 336             actions = self._predict(observation, deterministic=deterministic)
#     337         # Convert to numpy
#     338         actions = actions.cpu().numpy()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in _predict(self, observation, deterministic)
#     626         :return: Taken action according to the policy
#     627         """
# --> 628         return self.get_distribution(observation).get_actions(deterministic=deterministic)
#     629
#     630     def evaluate_actions(self, obs: th.Tensor, actions: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in get_distribution(self, obs)
#     653         :return: the action distribution.
#     654         """
# --> 655         features = self.extract_features(obs)
#     656         latent_pi = self.mlp_extractor.forward_actor(features)
#     657         return self._get_action_dist_from_latent(latent_pi)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in extract_features(self, obs)
#     127         assert self.features_extractor is not None, "No features extractor was set"
#     128         preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 129         return self.features_extractor(preprocessed_obs)
#     130
#     131     def _get_constructor_parameters(self) -> Dict[str, Any]:
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\torch_layers.py in forward(self, observations)
#      91
#      92     def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 93         return self.linear(self.cnn(observations))
#      94
#      95
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:
